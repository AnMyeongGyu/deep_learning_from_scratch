# %%
# implement basic step function
def step_function(x):
    if x > 0:
        return 1
    else:
        return 0
    
print(step_function(-1.5))
print(step_function(-0.7))
print(step_function(-0.3))
print(step_function(1.3))
print(step_function(3.0))
# Out:
# 0
# 0
# 0
# 1
# 1

# %%
import numpy as np

def step_function(x):
    y = x > 0
    return y.astype(np.int)

# %%
# check np.int function
x = np.array([-1.0, 1.0, 2.0])
print(x)
y = x > 0
print(y)
# Out:
# [-1.  1.  2.]
# [False  True  True]

# %%
# ignore warming message
import warnings
warnings.filterwarnings('ignore')

# bool type check
y = y.astype(np.int)
print(y)
# Out:
# [0 1 1]

# %%
# draw step function
import numpy as np
import matplotlib.pyplot as plt

def step_function(x):
    return np.array(x > 0, dtype = np.int)

x = np.arange(-5.0, 5.0, 0.1)
y = step_function(x)
plt.plot(x, y)
plt.ylim(-0.1, 1.1);

# %%
# implement sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.array([-1.0, 1.0, 2.0])
print(sigmoid(x))
# Out:
# [0.26894142 0.73105858 0.88079708]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)

y1 = np.exp(x)
y2 = np.exp(-x)

plt.plot(x, y1, label='exp(x)')
plt.plot(x, y2, label='exp(-x)')

plt.xlabel('x')
plt.ylabel('y')
plt.legend();

# %%
# compare sigmod vs step_function
# non linear function is important factor
# if we use linear function, it's not neural network model
# For exmaple, we can use h=c(x) and y(x)=h(h(h(x))) => y(x) = c*c*c*(x) = a(x) / c^3 = a

x = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(x)
y1 = step_function(x)

plt.plot(x, y)
plt.plot(x, y1, linestyle='dotted') # change line style
plt.ylim(-0.1, 1.1)

plt.show()

# %%
# implement ReLU function
def relu(x):
    return np.maximum(0, x)

x = np.arange(-5.0, 5.0, 0.1)
y = relu(x)
plt.plot(x, y);

# %%
# numpy dimension example
A = np.array([1, 2, 3, 4])
print(f"array A:\t\t{A}")
print(f"Dimension of A:\t\t{np.ndim(A)}")
print(f"Shape of A:\t\t{A.shape}")
print(f"A's first element:\t{A[0]}")
# Out:
# array A:		[1 2 3 4]
# Dimension of A:		1
# Shape of A:		(4,)
# A's first element:	1

# %%
B = np.array([[1,2], [3,4], [5,6]])
print(f"array A:\n{B}")
print(f"Dimension of A:\t\t{np.ndim(B)}")
print(f"Shape of A:\t\t{B.shape}")
# Out:
# array A:
# [[1 2]
#  [3 4]
#  [5 6]]
# Dimension of A:		2
# Shape of A:		(3, 2)

# %%
# matrix dot & cross example
print("A matrix:")
A = np.array([[1, 2], [3, 4]])
print(f'{A}\n')

print("B matrix:")
B = np.array([[5, 6], [7, 8]])
print(f'{B}\n')

print('dot A, B matrixs')
print(np.dot(A, B))
print()

print('dot B, A matrixs')
print(np.dot(B, A))
print()

print('cross A,B matrixs')
print(np.cross(A, B))
print()

print('cross B,A matrixs')
print(np.cross(B, A))
# Out:
# A matrix:
# [[1 2]
#  [3 4]]
#
# B matrix:
# [[5 6]
#  [7 8]]
#
# dot A, B matrixs
# [[19 22]
#  [43 50]]
#
# dot B, A matrixs
# [[23 34]
#  [31 46]]
#
# cross A,B matrixs
# [-4 -4]
#
# cross B,A matrixs
# [4 4]

# %%
# dot matrix in neural network
# X dot W = Y
# X shape is 2 / W shape is 2 X 3 / Y shape is 3

X = np.array([1, 2])
print(X.shape)
print()

W = np.array([[1, 3,5], [2, 4 ,6]])
print(W.shape)
print()

y = np.dot(X, W)
print(y)
# Out:
# (2,)
#
# (2, 3)
#
# [ 5 11 17]

# %%
X = np.array([1.0, 0.5])
W1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
B1 = np.array([0.1, 0.2, 0.3])

print(f'shape of X :\t{X.shape}')
print(f'shape of W1 :\t{W1.shape}')
print(f'shape of B1 :\t{B1.shape}')

A1 = np.dot(X, W1) + B1
# Out:
# shape of X :	(2,)
# shape of W1 :	(2, 3)
# shape of B1 :	(3,)

# %%
Z1 = sigmoid(A1)
print(A1)
print(Z1)
# Out:
# [0.3 0.7 1.1]
# [0.57444252 0.66818777 0.75026011]

# %%
W2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
B2 = np.array([0.1, 0.2])

print(f'shape of Z1 :\t{Z1.shape}')
print(f'shape of W2 :\t{W2.shape}')
print(f'shape of B2 :\t{B2.shape}')

A2 = np.dot(Z1, W2) + B2
Z2 = sigmoid(A2)

print('\nvalue of Z2')
print(Z2)
# Out:
# shape of Z1 :	(3,)
# shape of W2 :	(3, 2)
# shape of B2 :	(2,)
#
# value of Z2
# [0.62624937 0.7710107 ]

# %%
# output layer's activation function
# I used ReLU but book used identity function
def relu_function(x):
    return np.maximum(0, x)

W3 = np.array([[-0.1, -0.2], [0.2, 0.4]])
B3 = np.array([-0.2, 0.2])

A3 = np.dot(Z2, W3) + B3
print(A3)

print('\nafter activation function "ReLU"')
Y = relu_function(A3)
print(Y)
# Out:
# [-0.1084228  0.3831544]
#
# after activation function "ReLU"
# [0.        0.3831544]

# %%
# neural network implementation summary

def init_network():
    network = {}
    network['W1'] = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
    network['B1'] = np.array([0.1, 0.2, 0.3])
    network['W2'] = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
    network['B2'] = np.array([0.1, 0.2])
    network['W3'] = np.array([[-0.1, -0.2], [0.2, 0.4]])
    network['B3'] = np.array([-0.2, 0.2])

    return network

def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    B1, B2, B3 = network['B1'], network['B2'] ,network['B3']

    a1 = np.dot(x, W1) + B1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + B2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + B3
    z3 = sigmoid(a3)
    Y = relu_function(a3)

    return y

network = init_network()
x = np.array([1.0, 0.5])
y = forward(network, x)
print(Y)
# Out:
# [0.        0.3831544]

# %%
# implment soft max function
a = np.array([0.3, 2.9, 4.0])

exp_a = np.exp(a)
print(exp_a)
sum_exp_a = np.sum(exp_a)
print(sum_exp_a)
y = exp_a / sum_exp_a
print(y)
# Out:
# [ 1.34985881 18.17414537 54.59815003]
# 74.1221542101633
# [0.01821127 0.24519181 0.73659691]

# %%
def softmax(a):
    exp_a = np.exp(a)
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a
    return y

# %%
# softmax function's overflow flaw
# we can see nan value
a = np.array([1010, 1000, 990])
print(np.exp(a) / np.sum(np.exp(a)))

# To solve this problem we can subtract array's max value C
c = np.max(a)
print(a - c)

print(np.exp(a-c) / np.sum(np.exp(a-c)))
# Out:
# [nan nan nan]
# [  0 -10 -20]
# [9.99954600e-01 4.53978686e-05 2.06106005e-09]

# %%
# overflow flaw solved softmax function
def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a-c)
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a

    return y

# %%
a = np.array([0.3, 2.9, 4.0])
y = softmax(a)
print(y)
print(np.sum(y))
# Out:
# [0.01821127 0.24519181 0.73659691]
# 1.0

# %%
# MNIST example
import sys, os

# Need to download MNIST dataset and Make directory 'dataset'
# https://github.com/oreilly-japan/deep-learning-from-scratch/tree/master/dataset

# This allows you to use modules located in that directory, such as mnist.py.
sys.path.append('D:\study\book\Deep+learning_from_scratch')

# The line from dataset.mnist import load_mnist means that you want to import the load_mnist function from the mnist.py module located in the dataset directory.
# This line enables you to access and use the load_mnist function in your current Python script.
from dataset.mnist import load_mnist

(X_train, t_train), (X_test, t_test) = load_mnist(flatten = True, normalize= False)

print(X_train.shape)
print(t_train.shape)
print(X_test.shape)
print(t_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
(X_train, t_train), (X_test, t_test) = load_mnist(flatten = True, normalize= False)

img = X_train[0]
label = t_train[0]
print(label)
print(img.shape)
img = img.reshape(28, -1)
print(img.shape)

# This book used below code but i think it's hard to check image so i used matplotlib
#
# show image file with viewer
# from PIL import Image

# def img_show(img):
#     pil_img = Image.fromarray(np.uint8(img))
#     pil_img.show()

# img_show(img) 

plt.imshow(img, cmap='gray') 
plt.axis('off');
# Out:
# 5
# (784,)
# (28, 28)

# %%
os.chdir('G:/내 드라이브/book/Deep+learning_from_scratch/dataset/')
import pickle

def get_data():
    (X_train, t_train), (X_test, t_test) = load_mnist(flatten = True, normalize= True, one_hot_label= False)
    return X_test, t_test

def init_network():
    with open('sample_weight.pkl', 'rb') as f:
        network = pickle.load(f)

    return network

def predict(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    B1, B2, B3 = network['b1'], network['b2'] ,network['b3']

    a1 = np.dot(x, W1) + B1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + B2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + B3
    y = softmax(a3)

    return y

# %%
x, t = get_data()
network = init_network()

accuray_cnt = 0
for i in range(len(x)):
    y = predict(network, x[i])
    p = np.argmax(y)
    if p == t[i]:
        accuray_cnt += 1

print('accuracy: ' + str(float(accuray_cnt)/ len(x)))
# Out:
# accuracy: 0.9352

# %%
# check weights
# we can see the matrix fit each other
x, b = get_data()
network = init_network()
W1, W2, W3 = network['W1'], network['W2'], network['W3']

print(x.shape)
print(x[0].shape)
print(W1.shape)
print(W2.shape)
print(W3.shape)
# Out:
# (10000, 784)
# (784,)
# (784, 50)
# (50, 100)
# (100, 10)

# %%
# check biases
B1, B2, B3 = network['b1'], network['b2'] ,network['b3']

print(b.shape)
print(b[0])
print(B1.shape)
print(B2.shape)
print(B3.shape)
# Out:
# (10000,)
# 7
# (50,)
# (100,)
# (10,)

# %%
# implement batch processing
x, t = get_data()
network = init_network()

batch_size = 100
accuray_cnt = 0

for i in range(0, len(x), batch_size):
    x_batch = x[i:i+batch_size]
    y_batch = predict(network, x_batch)
    p = np.argmax(y_batch, axis = 1) # how about axis = 0 ? what is problem
    accuray_cnt += np.sum(p == t[i: i+batch_size])

print('accuray: ' + str(float(accuray_cnt) / len(x)))
# Out:
# accuray: 0.9352

# %%
# change the argmax's parameter value to 0
x, t = get_data()
network = init_network()

batch_size = 100
accuray_cnt = 0

import pandas as pd

for i in range(0, 100, batch_size):
    x_batch = x[i:i+batch_size]
    y_batch = predict(network, x_batch)
    p = np.argmax(y_batch, axis = 0)

    # how about axis = 0
    # np.argmax is return of max value's index 
    # so max value's index will not match to label(0 ~ 9) so it makes 0% accuracy.
    # we must know we are using softmax function
    print(y_batch.shape)
    print(p.shape)  
    print(p) # p is index of max value 
    accuray_cnt += np.sum(p == t[i: i+batch_size])

print('accuray: ' + str(float(accuray_cnt) / 100))
# Out:
# (100, 10)
# (10,)
# [71 14 82 90 85 23 91 70 61 99]
# accuray: 0.0
